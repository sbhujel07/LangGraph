# %%
import os

if "GROQ_API_KEY" not in os.environ:
    raise ValueError("GROQ_API_KEY environment variable not set. Please set it to your Groq API key.")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant",temperature=0.5)
response = llm.invoke("What is the capital of France?")
print(response)
# Out:
# content='The capital of France is Paris.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 42, 'total_tokens': 50, 'completion_time': 0.008019952, 'completion_tokens_details': None, 'prompt_time': 0.002834331, 'prompt_tokens_details': None, 'queue_time': 0.068577084, 'total_time': 0.010854283}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e01fb-a16e-71c2-917e-c536488dc917-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 8, 'total_tokens': 50}

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages([
    ("system","You are a helpful assistant can help me create a post about any topic"),
    ("human","I want to create a post about {topic}"),
]
)

prompt = my_prompt.invoke({"topic":"about the latest ai technology"})

# %%
llm.invoke(prompt).content
# Out:
# 'Here\'s a potential post on the latest AI technology:\n\n**Title:** "Revolutionizing the Future: The Latest Advances in AI Technology"\n\n**Introduction:**\n\nArtificial Intelligence (AI) has been a rapidly evolving field in recent years, with significant breakthroughs and innovations transforming the way we live and work. From chatbots and virtual assistants to self-driving cars and personalized medicine, AI is increasingly becoming an integral part of our daily lives. In this post, we\'ll explore the latest developments in AI technology and what they mean for the future.\n\n**Latest AI Advancements:**\n\n1. **Quantum AI:** Researchers have been exploring the potential of quantum computing to accelerate AI processing and improve its accuracy. Quantum AI uses quantum bits (qubits) to perform complex calculations, enabling AI systems to learn and adapt at unprecedented speeds.\n2. **Edge AI:** With the proliferation of IoT devices, Edge AI has emerged as a key technology to enable re
# ...

# %% [markdown]
# We can also make a chain using langchain so

# %% [markdown]
# CHAIN WITH PROMPTS

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic":"about the latest ar technology"})
# Out:
# AIMessage(content="Here's a potential post on the latest AR technology:\n\n---\n\n**The Future of Reality: Exploring the Latest Advancements in Augmented Reality (AR)**\n\nAugmented Reality (AR) has been a buzzword in the tech industry for years, and it's finally starting to become a reality. From gaming and education to healthcare and retail, AR is transforming the way we interact with the world around us. In this post, we'll dive into the latest advancements in AR technology and explore its potential applications.\n\n**Latest AR Innovations:**\n\n1. **Light Field Displays**: Light field displays are a new type of display technology that can project high-resolution images with depth and perspective. This allows for a more immersive AR experience, making it feel like the virtual objects are truly part of the real world.\n2. **Advanced Tracking Systems**: AR requires precise tracking of the user's movements and orientation. New tracking systems use machine learning algorithms and comp
# ...
