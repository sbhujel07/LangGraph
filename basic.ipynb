# %%
from langchain_openai import OpenAI

llm = OpenAI(model="gpt-5-nano", temperature=0.5)
llm("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain_openai import OpenAI
#       2
#       3 llm = OpenAI(model="gpt-5-nano", temperature=0.5)
# ----> 4 llm("What is the capital of France?")
#
# TypeError: 'OpenAI' object is not callable
